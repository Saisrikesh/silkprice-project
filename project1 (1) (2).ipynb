# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv',na_values='=')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23093 entries, 0 to 23092
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        23093 non-null  object
#  1   district     23093 non-null  object
#  2   market       23093 non-null  object
#  3   commodity    23093 non-null  object
#  4   date         23093 non-null  object
#  5   min_price    23093 non-null  float64
#  6   max_price    23093 non-null  float64
#  7   modal_price  23093 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# state          0
# district       0
# market         0
# commodity      0
# date           0
# min_price      0
# max_price      0
# modal_price    0
# dtype: int64

# %%
df.head(6)
# Out:
#      state district    market              commodity        date  min_price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)  27/07/2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal  27/07/2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage  27/07/2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower  27/07/2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)  27/07/2023     8400.0
# 5  Gujarat   Amreli  Damnagar          Ginger(Green)  27/07/2023    11000.0
#
#    max_price  modal_price
# 0     4500.0       4350.0
# 1     3000.0       2450.0
# 2     3000.0       2700.0
# 3     7500.0       7250.0
# 4     9000.0       8850.0
# 5    14000.0      12500.0

# %%
df.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'date', 'min_price',
#        'max_price', 'modal_price'],
#       dtype='object')

# %%
data2=df.head(20000)

# %%
data2.shape
# Out:
# (20000, 8)

# %%
data2=data2.dropna()

# %%
data2.head()
# Out:
#      state district    market              commodity        date  min_price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)  27/07/2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal  27/07/2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage  27/07/2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower  27/07/2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)  27/07/2023     8400.0
#
#    max_price  modal_price
# 0     4500.0       4350.0
# 1     3000.0       2450.0
# 2     3000.0       2700.0
# 3     7500.0       7250.0
# 4     9000.0       8850.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        20000 non-null  object
#  1   district     20000 non-null  object
#  2   market       20000 non-null  object
#  3   commodity    20000 non-null  object
#  4   date         20000 non-null  object
#  5   min_price    20000 non-null  float64
#  6   max_price    20000 non-null  float64
#  7   modal_price  20000 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 1.2+ MB

# %%
data2.isnull().sum()
# Out:
# state          0
# district       0
# market         0
# commodity      0
# date           0
# min_price      0
# max_price      0
# modal_price    0
# dtype: int64

# %%
data2=data2.head(20000)

# %%
data2.shape
# Out:
# (20000, 8)

# %%
# Python split() method example
# Variable declaration
str = data2["date"][1]
# Calling function
str2 = str.split('/')
# Displaying result
print(str)
print(str2)
print(str2[1])
# Out:
# 27/07/2023
# ['27', '07', '2023']
# 07

# %%
Dict = {1:"January", 2:"February",3: "March",4: "April",5: "May", 6: "June", 7:"July", 8: "August", 9: "September", 10: "October", 11: "November", 12: "December"}
print (Dict)
# Out:
# {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# %%
Dict[1]
# Out:
# 'January'

# %%
month_column=[]

# %%
# Python split() method example
 # Variable declaration
for rr in data2["date"]:
  str =rr
  # Calling function I
  str2 = str.split('/')
  #Displaying result
  ##print(str)
  #print(str2)
  #print(str2[1])
  #print (Dict[int(str2[1])])
  month_column.append(Dict[int(str2[1])])

# %%
len(month_column)
# Out:
# 20000

# %%
data2["month_column"]=month_column

# %%
data2["month_column"]
# Out:
# 0          July
# 1          July
# 2          July
# 3          July
# 4          July
#           ...
# 19995    August
# 19996    August
# 19997    August
# 19998    August
# 19999    August
# Name: month_column, Length: 20000, dtype: object

# %%
data2["month_column"].unique()
# Out:
# array(['July', 'August'], dtype=object)

# %%
season_names=[]

# %%
print(len(season_names))
count=0
for tt in data2["month_column"]:
  count=count+1
  if tt=="January" or tt=="February":
    # print("winter")
    season_names.append("winter")
  elif tt=="March" or tt=="April":
    #print("spring)
    season_names.append("spring")
  elif tt=="May" or tt=="June":
    #print("summer")
    season_names.append("summer")
  elif tt=="July" or tt=="August":
    #print("monsoon")
    season_names.append("monsoon")
  elif tt=="September "or tt=="October":
    #print("autumn")
    season_names.append("autumn")
  elif tt=="November "or tt== "December":
    #print("pre winter")
    season_names.append("pre winter")
print(len(season_names))
# Out:
# 0
# 20000

# %%
data2["season_names"]=season_names

# %%
data2.head()
# Out:
#      state district    market              commodity        date  min_price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)  27/07/2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal  27/07/2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage  27/07/2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower  27/07/2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)  27/07/2023     8400.0
#
#    max_price  modal_price month_column season_names
# 0     4500.0       4350.0         July      monsoon
# 1     3000.0       2450.0         July      monsoon
# 2     3000.0       2700.0         July      monsoon
# 3     7500.0       7250.0         July      monsoon
# 4     9000.0       8850.0         July      monsoon

# %%
import pandas as pd
df = pd.Timestamp("2019-04-12")
print(df.dayofweek)
# Out:
# 4

# %%
day_of_week=[]

# %%
for rr in data2["date"]:
  str=rr
  df = pd.Timestamp(rr)
  day = df.dayofweek
  day_of_week.append(day)
# Out:
# <ipython-input-36-79ab4f10c782>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.Timestamp(rr)

# %%
len(day_of_week)
# Out:
# 20000

# %%
data2["day"]=day_of_week

# %%
data2.tail()
# Out:
#            state   district                         market  \
# 19995  Telangana   Nalgonda               Venkateswarnagar
# 19996  Telangana   Nalgonda               Venkateswarnagar
# 19997  Telangana   Nalgonda  Venkateswarnagar(Chintapalli)
# 19998  Telangana   Nalgonda                      Voligonda
# 19999  Telangana  Nizamabad                         Armoor
#
#                  commodity        date  min_price  max_price  modal_price  \
# 19995               Potato  01/08/2023     3000.0     3000.0       3000.0
# 19996     Ridgeguard(Tori)  01/08/2023     3500.0     3500.0       3500.0
# 19997  Paddy(Dhan)(Common)  01/08/2023     2060.0     2060.0       2060.0
# 19998  Paddy(Dhan)(Common)  01/08/2023     2060.0     2060.0       2060.0
# 19999  Paddy(Dhan)(Common)  01/08/2023     2040.0     2060.0       2040.0
#
#       month_column season_names  day
# 19995       August      monsoon    6
# 19996       August      monsoon    6
# 19997       August      monsoon    6
# 19998       August      monsoon    6
# 19999       August      monsoon    6

# %%
data2=data2.drop('date', 1)
# Out:
# <ipython-input-40-0b9a158e71fb>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data2=data2.drop('date', 1)

# %%
data2.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'min_price', 'max_price',
#        'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
data2=data2.head(20000)

# %%
import seaborn as sns
sns.boxplot(data2['modal_price'])
# Out:
# <Axes: >

# %%
data2.shape
# Out:
# (20000, 10)

# %%
data2['modal_price']
# Out:
# 0        4350.0
# 1        2450.0
# 2        2700.0
# 3        7250.0
# 4        8850.0
#           ...
# 19995    3000.0
# 19996    3500.0
# 19997    2060.0
# 19998    2060.0
# 19999    2040.0
# Name: modal_price, Length: 20000, dtype: float64

# %%
Q1 = np.percentile(data2['modal_price'], 25, interpolation = "midpoint")
Q3 = np.percentile(data2['modal_price'], 75, interpolation = "midpoint")
IQR = Q3 - Q1
# Out:
# <ipython-input-46-a66a97a3adf0>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data2['modal_price'], 25, interpolation = "midpoint")
# <ipython-input-46-a66a97a3adf0>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data2['modal_price'], 75, interpolation = "midpoint")

# %%
upper = np.where(data2['modal_price'] >= (Q3+1.5*IQR))
lower = np.where(data2['modal_price'] <= (Q1-1.5*IQR))

# %%
print(upper[0],lower[0])
# Out:
# [    5    10    11 ... 19877 19918 19975] []

# %%
data2.drop(upper[0], inplace = True)
data2.drop(lower[0], inplace = True)
print("New Shape: ", data2.shape)
# Out:
# New Shape:  (18752, 10)

# %%
sns.boxplot(data2['modal_price'])
# Out:
# <Axes: >

# %%
df=data2.copy()

# %%
data2.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'min_price', 'max_price',
#        'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
import plotly.express as px

# %%
sns.relplot(data=df, x="state", y="modal_price", hue="season_names", kind="line")

# %%
sns.relplot(data=df, x="district", y="modal_price", hue="season_names", kind="line")

# %%
sns.relplot(data=df, x="season_names", y="modal_price", hue="season_names", kind="line")

# %%
sns.relplot(data=df, x="day", y="modal_price", hue="season_names", kind="line")

# %%
data2.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'min_price', 'max_price',
#        'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
sns.relplot(data=df, x="market", y="modal_price", hue="season_names", kind="line")

# %%
sns.relplot(data=df, x="month_column", y="modal_price", hue="season_names", kind="line")

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18752 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         18752 non-null  object
#  1   district      18752 non-null  object
#  2   market        18752 non-null  object
#  3   commodity     18752 non-null  object
#  4   min_price     18752 non-null  float64
#  5   max_price     18752 non-null  float64
#  6   modal_price   18752 non-null  float64
#  7   month_column  18752 non-null  object
#  8   season_names  18752 non-null  object
#  9   day           18752 non-null  int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
dist = (data2['commodity'])
distset=set(dist)
dd=list(distset)
dictOfWords = { dd[i]: i for i in range(0, len (dd)) }
data2['commodity']=data2['commodity'].map(dictOfWords)

# %%
print(data2['commodity'])
# Out:
# 0         88
# 1         10
# 2         29
# 3        175
# 4         27
#         ...
# 19995     37
# 19996     73
# 19997      0
# 19998      0
# 19999      0
# Name: commodity, Length: 18752, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data2['market']=le.fit_transform(data2['market'])
data2['state']=le.fit_transform(data2['state'])
data2['district']=le.fit_transform(data2['district'])
data2['month_column']=le.fit_transform(data2['month_column'])
data2['season_names']=le.fit_transform(data2['season_names'])

# %%
print(data2['market'])
print(data2['state'])
print(data2['district'])
print(data2['month_column'])
print(data2['season_names'])
# Out:
# 0         288
# 1         288
# 2         288
# 3         288
# 4         288
#          ...
# 19995    1172
# 19996    1172
# 19997    1173
# 19998    1186
# 19999      66
# Name: market, Length: 18752, dtype: int64
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 19995    21
# 19996    21
# 19997    21
# 19998    21
# 19999    21
# Name: state, Length: 18752, dtype: int64
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#         ...
# 19995    259
# 19996    259
# 19997    259
# 19998    259
# 19999    269
# Name: district, Length: 18752, dtype: int64
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: month_column, Length: 18752, dtype: int64
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: season_names, Length: 18752, dtype: int64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18752 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         18752 non-null  int64
#  1   district      18752 non-null  int64
#  2   market        18752 non-null  int64
#  3   commodity     18752 non-null  int64
#  4   min_price     18752 non-null  float64
#  5   max_price     18752 non-null  float64
#  6   modal_price   18752 non-null  float64
#  7   month_column  18752 non-null  int64
#  8   season_names  18752 non-null  int64
#  9   day           18752 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 2.1 MB

# %%
import matplotlib.pyplot as plt

# %%
#print(data2.corr())
# plotting correlation heatmap I
dataplot =sns.heatmap(data2.corr(), cmap="YlGnBu", annot=True)
#displaying heatmap
plt.show()

# %%
#train and test spilt data

# %%
#training multiple models

# %%
data2.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'min_price', 'max_price',
#        'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
features= data2 [['commodity', 'state', 'district', 'market', 'month_column', 'season_names', 'day']]
labels = data2['modal_price']

# %%
data2.head()
# Out:
#    state  district  market  commodity  min_price  max_price  modal_price  \
# 0      5        12     288         88     4100.0     4500.0       4350.0
# 1      5        12     288         10     2200.0     3000.0       2450.0
# 2      5        12     288         29     2350.0     3000.0       2700.0
# 3      5        12     288        175     7000.0     7500.0       7250.0
# 4      5        12     288         27     8400.0     9000.0       8850.0
#
#    month_column  season_names  day
# 0             1             0    3
# 1             1             0    3
# 2             1             0    3
# 3             1             0    3
# 4             1             0    3

# %%
# Splitting into train and test data

from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(features, labels, test_size =0.2, random_state =2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

regr= RandomForestRegressor (max_depth=1000, random_state=0)
regr.fit(Xtrain, Ytrain)

#print (regr.predict(Ytest[0]))
# Out:
# RandomForestRegressor(max_depth=1000, random_state=0)

# %%
data2.info
# Out:
# <bound method DataFrame.info of        state  district  market  commodity  min_price  max_price  modal_price  \
# 0          5        12     288         88     4100.0     4500.0       4350.0
# 1          5        12     288         10     2200.0     3000.0       2450.0
# 2          5        12     288         29     2350.0     3000.0       2700.0
# 3          5        12     288        175     7000.0     7500.0       7250.0
# 4          5        12     288         27     8400.0     9000.0       8850.0
# ...      ...       ...     ...        ...        ...        ...          ...
# 19995     21       259    1172         37     3000.0     3000.0       3000.0
# 19996     21       259    1172         73     3500.0     3500.0       3500.0
# 19997     21       259    1173          0     2060.0     2060.0       2060.0
# 19998     21       259    1186          0     2060.0     2060.0       2060.0
# 19999     21       269      66          0     2040.0     2060.0       2040.0
#
#        month_column  season_names  day
# 0                 1             0    3
# 1                 1             0    3
# 2                 1             0    3
# 3                 1             0    3
# 4                 1             0    3
# ...             ...           ...  ...
# 19995             0             0    6
# 19996             0             0    6
# 19997             0             0    6
# 19998             0             0    6
# 19999             0             0    6
#
# [18752 rows x 10 columns]>

# %%
Xtest[0:1]
# Out:
#      commodity  state  district  market  month_column  season_names  day
# 942         88      6       215    1093             1             0    4

# %%
y_pred=regr.predict(Xtest)

# %%
from sklearn.metrics import r2_score

# %%
data2.shape
# Out:
# (18752, 10)

# %%
r2_score (Ytest, y_pred)
# Out:
# 0.7920545437300985

# %%
y_pred
# Out:
# array([3257.5 , 1272.75, 3264.  , ..., 1342.5 , 6300.  , 4357.5 ])

# %%
data2.columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'min_price', 'max_price',
#        'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
Xtest[0:1]
# Out:
#      commodity  state  district  market  month_column  season_names  day
# 942         88      6       215    1093             1             0    4
